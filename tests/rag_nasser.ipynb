# %%
from langchain_community.document_loaders import UnstructuredPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
# Function to load and split the data from the PDF file
def load_and_split_data(file_path):
    # Load the PDF file and split the data into chunks
    loader = UnstructuredPDFLoader(file_path=file_path)
    data = loader.load()
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=7500, chunk_overlap=100)
    chunks = text_splitter.split_documents(data)

    return chunks

load_and_split_data("/home/drunkwcodes/Documents/大家的日本语1-2册教材/01.pdf")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/bb7/.venv/lib/python3.12/site-packages/pandas/__init__.py:26
#      24 try:
#      25     # numpy compat
# ---> 26     from pandas.compat import (
#      27         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401
#      28     )
#      29 except ImportError as _err:  # pragma: no cover
#
# ModuleNotFoundError: No module named 'pandas.compat'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 11
#       7     chunks = text_splitter.split_documents(data)
#       9     return chunks
# ---> 11 load_and_split_data("/home/drunkwcodes/Documents/大家的日本语1-2册教材/01.pdf")
#
# Cell In[7], line 5, in load_and_split_data(file_path)
#       2 def load_and_split_data(file_path):
#       3     # Load the PDF file and split the data into chunks
#       4     loader = UnstructuredPDFLoader(file_path=file_path)
# ----> 5     data = loader.load()
#       6     text_splitter = RecursiveCharacterTextSplitter(chunk_size=7500, chunk_overlap=100)
#       7     chunks = text_splitter.split_documents(data)
#
# File ~/projects/bb7/.venv/lib/python3.12/site-packages/langchain_core/document_loaders/base.py:31, in BaseLoader.load(self)
#      29 def load(self) -> list[Document]:
#      30     """Load data into Document objects."""
# ---> 31     return list(self.lazy_load())
#
# File ~/projects/bb7/.venv/lib/python3.12/site-packages/langchain_community/document_loaders/unstructured.py:107, in UnstructuredBaseLoader.lazy_load(self)
#     105 def lazy_load(self) -> Iterator[Document]:
#     106     """Load file."""
# --> 107     elements = self._get_elements()
#     108     self._post_process_elements(elements)
#     109     if self.mode == "elements":
#
# File ~/projects/bb7/.venv/lib/python3.12/site-packages/langchain_community/document_loaders/pdf.py:72, in UnstructuredPDFLoader._get_elements(self)
#      71 def _get_elements(self) -> List:
# ---> 72     from unstructured.partition.pdf import partition_pdf
#      74     return partition_pdf(filename=self.file_path, **self.unstructured_kwargs)
#
# File ~/projects/bb7/.venv/lib/python3.12/site-packages/unstructured/partition/pdf.py:81
#      72 from unstructured.partition.lang import (
#      73     check_languages,
#      74     prepare_languages_for_tesseract,
#      75 )
#      76 from unstructured.partition.pdf_image.pdf_image_utils import (
#      77     annotate_layout_elements,
#      78     check_element_types_to_extract,
#      79     save_elements,
#      80 )
# ---> 81 from unstructured.partition.pdf_image.pdfminer_processing import (
#      82     merge_inferred_with_extracted_layout,
#      83 )
#      84 from unstructured.partition.pdf_image.pdfminer_utils import (
#      85     open_pdfminer_pages_generator,
#      86     rect_to_bbox,
#      87 )
#      88 from unstructured.partition.strategies import determine_pdf_or_image_strategy, validate_strategy
#
# File ~/projects/bb7/.venv/lib/python3.12/site-packages/unstructured/partition/pdf_image/pdfminer_processing.py:9
#       3 from pdfminer.utils import open_filename
#       4 from unstructured_inference.inference.elements import (
#       5     EmbeddedTextRegion,
#       6     ImageTextRegion,
#       7     TextRegion,
#       8 )
# ----> 9 from unstructured_inference.inference.layoutelement import (
#      10     merge_inferred_layout_with_extracted_layout as merge_inferred_with_extracted_page,
#      11 )
#      12 from unstructured_inference.inference.ordering import order_layout
#      13 from unstructured_inference.models.detectron2onnx import UnstructuredDetectronONNXModel
#
# File ~/projects/bb7/.venv/lib/python3.12/site-packages/unstructured_inference/inference/layoutelement.py:7
#       4 from typing import Collection, List, Optional
#       6 import numpy as np
# ----> 7 from layoutparser.elements.layout import TextBlock
#       8 from pandas import DataFrame
#       9 from PIL import Image
#
# File ~/projects/bb7/.venv/lib/python3.12/site-packages/layoutparser/elements/__init__.py:16
#       1 # Copyright 2021 The Layout Parser team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .base import BaseCoordElement, BaseLayoutElement
# ---> 16 from .layout_elements import (
#      17     Interval,
#      18     Rectangle,
#      19     Quadrilateral,
#      20     TextBlock,
#      21     ALL_BASECOORD_ELEMENTS,
#      22     BASECOORD_ELEMENT_NAMEMAP,
#      23     BASECOORD_ELEMENT_INDEXMAP,
#      24 )
#      25 from .layout import Layout
#
# File ~/projects/bb7/.venv/lib/python3.12/site-packages/layoutparser/elements/layout_elements.py:23
#      20 import functools
#      22 import numpy as np
# ---> 23 import pandas as pd
#      24 from PIL import Image
#      25 from cv2 import getPerspectiveTransform as _getPerspectiveTransform
#
# File ~/projects/bb7/.venv/lib/python3.12/site-packages/pandas/__init__.py:31
#      29 except ImportError as _err:  # pragma: no cover
#      30     _module = _err.name
# ---> 31     raise ImportError(
#      32         f"C extension: {_module} not built. If you want to import "
#      33         "pandas from the source directory, you may need to run "
#      34         "'python setup.py build_ext' to build the C extensions first."
#      35     ) from _err
#      37 from pandas._config import (
#      38     get_option,
#      39     set_option,
#    (...)
#      43     options,
#      44 )
#      46 # let init-time option registration happen
#
# ImportError: C extension: pandas.compat not built. If you want to import pandas from the source directory, you may need to run 'python setup.py build_ext' to build the C extensions first.
